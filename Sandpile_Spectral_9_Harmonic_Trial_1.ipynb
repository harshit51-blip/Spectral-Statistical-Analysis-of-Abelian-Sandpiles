# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import random as r
import seaborn as sns
from itertools import chain

# %%
#list_1 = np.array(np.arange(1,11,1))
#list_2 = np.array(np.arange(1,101,1).reshape(10,10))
'''b = r.choice(list_2)
b_2 = r.choice(b)'''
def a(g, l, phi, v, d):
    return (g*np.sin(phi)/l) - d*v
def a_w(g, l, phi):
    return (g*np.sin(phi)/l)

def integrator(s):
    deltaT = 0.1
    tFinal = 5.0
    N = int(tFinal/deltaT)

    T = np.zeros(N+1, float)
    xtheta = np.zeros(N+1, float)
    Vx = np.zeros(N+1, float)
    ytheta = np.zeros(N+1, float)
    Vy = np.zeros(N+1, float)


    g = 9.81
    dx = 0.1
    dy = 0.1
    
    lst = list(range(1,101))
    for _ in lst:
        xl = 1.0
        yl = 1.0
        xtheta[0] = r.choice(s)
        Vx[0] = (deltaT/2.0) * a_w(g, xl, xtheta[0])
        ytheta[0] = r.choice(s)
        Vy[0] = (deltaT/2.0) * a_w(g, yl, ytheta[0])

        for n in range(1, N+1):
            T[n] = n * deltaT
            xtheta[n] = xtheta[n-1] + Vx[n-1] * deltaT
            Vx[n] = Vx[n-1] + a(g, xl, xtheta[n], Vx[n-1], dx) * deltaT
            ytheta[n] = ytheta[n-1] + Vy[n-1] * deltaT
            Vy[n] = Vy[n-1] + a(g, yl, ytheta[n], Vy[n-1], dy) * deltaT
            
    return list(xtheta), list(ytheta)





def func(N):
    list_5 = []
    list_6 = []
    w_list = []
    list_7 = []
    list_8 = []
    cout = []
    k_list = list(np.arange(1,10,1))
    counter = 0
    xlist = []
    ylist = []
    
    for t in range(250):
        
        mat = np.random.random((N,N))
        
        xlist, ylist = integrator(r.choice(mat))
        matf = list(zip(xlist,ylist))
        matf = mat + mat.conj().T
        
        
        for i in matf:
            
            a = r.choice(matf)
            j_prime = np.where(matf == a)
            a_2 = r.choice(a)
            j = np.where(matf[j_prime] == a_2)
            a_2 += 1
            matf[j_prime][j] = a_2
            list_7.append(a_2)

            list_3 = [i-1, i+1]
            for o in a:
                for k in k_list:
                    u = r.uniform(a_2**k + 5, a_2**(k-1) + 2)
                    if o > u:
                        b = r.choice(list_3)
                        n = np.where(matf[j_prime] == o)
                        o -= abs(u-o)
                        b += abs(u-o)
                        matf[j_prime][n] = b
            
                    


                        '''if 0 == list_1[0]:
                            list_3 = [x+1]
                            b = r.choice(list_3)
                            n = np.where(list_1 == x)
                            x -= 1
                            b += 1
                            list_1[n] = b'''



                        if o == matf[j_prime][N-1]:
                            list_3 = [x-1]
                            b = r.choice(list_3)
                            n = np.where(matf[j_prime] == o)
                            o -= abs(u-o)
                            b += abs(u-o)
                            matf[j_prime][n] = b
                               
                   
                list_8.append(o)
                
                list_6.append(u)
            
                
            counter+=1
            
            list_5.append(i)
            cout.append(counter)
        
        
        w = np.linalg.eigvals(mat)
        h = list(w)
        w_list.append(h)
        w_list.sort()
        
        
    return w_list, list_5, list_6, list_7, cout

# %%
#N_list = [50, 60, 80, 100, 120, 150, 200, 240, 270, 300]
#N_2 = [200, 250, 300, 350, 400, 450, 500]
N_3 = list(np.arange(5, 200, 10))
#N_4 = [120]
list_m = []
list_c = []
deviation = []
r_dev = []
r_mean = []
c_dev = []
c_mean = []

for p in N_3:
    
    eig_vals, raw_list, crit_points, mean, clist = func(p)
    raw_list_2 =  list(chain.from_iterable(raw_list))
    eig_vals_2 = list(chain.from_iterable(eig_vals))
    norm_eig = [a/np.sqrt(p) for a in eig_vals_2]
    evd2 = [abs(y - x) for x,y in zip(norm_eig, norm_eig[1:])]
    mean_evd2 = evd2/(np.mean(evd2))
    rld2 = [y - x for x,y in zip(raw_list_2, raw_list_2[1:])]
    #d = {'list%s' % i: mean_evd2 for i in range(len(N_3))}
    list_m.append(mean_evd2)
    list_c.append(crit_points)
    dev = st.stdev(evd2)
    m = st.mean(evd2)
    dev_r = st.stdev(rld2)
    m_r = st.mean(rld2)
    m_c = st.mean(crit_points)
    dev_c = st.stdev(crit_points)
    deviation.append(dev)
    list_m.append(m)
    r_dev.append(dev_r)
    r_mean.append(m_r)
    c_dev.append(dev_c)
    c_mean.append(m_c)
    
    
    print('done')
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done

# %%
print(len(crit_points))
print(len(evd2))
print(len(mean_evd2))
print(len(rld2))


print(deviation)
print(list_m)
print(r_dev)
print(r_mean)
print(c_dev)
print(c_mean)
# Out:
# 9506250
# 48749
# 48749
# 9506249
# [0.4579836402910418, 0.5910988444987856, 0.6237997635797089, 0.6434355926692275, 0.6522630786243906, 0.6613120302349706, 0.667740668525862, 0.6718154743821249, 0.6763648916629547, 0.6786671329393038, 0.6801172260352158, 0.6821963790849653, 0.686048010757831, 0.6820850680175546, 0.684619174147672, 0.6873927028502632, 0.6884101691913029, 0.6901629515708697, 0.6892933175334622, 0.6910668275231332]
# [array([1.06345431, 0.25247365, 0.09981296, ..., 0.70888354, 0.83278061,
#        0.44990076]), 0.603739731558114, array([3.91191972, 1.04084657, 0.94269378, ..., 0.24367829, 0.12445411,
#        0.26128154]), 0.48006072551851414, array([6.10315133, 0.16245471, 0.24086081, ..., 0.2340192 , 0.12953031,
#        0.06955104]), 0.43874013942729617, array([6.34000531, 0.92948512, 0.63926699, ..., 0.38508547, 0.1926094 ,
#        0.13339055]), 0.414660916054915, array([7.30623384, 1.08479657, 1.29912374, ..., 0.03830958, 0.09052074,
# [2292.227550951486, 1894.6141426546644, 1913.0846846294987, 1953.0809354488115, 1849.6612801261165, 1903.7866337007667, 1889.5473250903074, 1864.3985331585338, 1871.3176498038042, 1890.1494386637487, 1878.6663986111037, 1851.5989194733554, 1877.9070807004719, 1837.97038484683, 1857.6053860684108, 1840.711356103797, 1890.8311587079804, 1845.9505881978414, 1852.0575945588437, 1852.9238853653096]
# [1363.7908298356062, 1140.792295543122, 1129.8605506220772, 1167.3037867343526, 1108.1430227542755, 1138.0844938980385, 1122.2695482161284, 1102.022619250537, 1124.0854600743387, 1135.4530948852557, 1124.1593167683477, 1103.2492800489501, 1126.1679422792129, 1100.089263469934, 1111.5834502317525, 1102.8524846601383, 1132.7874215207326, 1104.1777144654598, 1120.5763626746077, 1101.471023792122]

# %%
plt.scatter(N_3, deviation)
plt.xlabel('Lattice Size')
plt.ylabel('deviation in eigen values')
plt.show()


plt.scatter(np.log(N_3[2:]), np.log(deviation[2:]))
m, c = np.polyfit(np.log(N_3[2:]), np.log(deviation[2:]), 1)
ytrend = [m*a+c for a in np.log(N_3[2:])]
plt.xlabel('log of Lattice Size')
plt.ylabel('log of deviation in eigen values')
plt.plot(np.log(N_3[2:]), ytrend)

print(m, c)
plt.show()

'''plt.scatter(r_dev, list_m)
plt.xlabel('Lattice Size')
plt.ylabel('Mean of eigen values')
plt.show()

plt.scatter(N_3, list_m)
m_1, c_1 = np.polyfit(N_3, [1/v for v in list_m], 1)
ytrend_1 = [m_1*f+c_1 for f in N_3]
plt.plot(N_3, ytrend_1)
plt.xlabel('Lattice Size')
plt.ylabel('$1/(Mean of eigen values)$')
print(m_1, c_1)
plt.show()'''

plt.scatter(np.log(r_dev), np.log(c_dev))
plt.xlabel('Lattice Size')
plt.ylabel('deviation in evolution of lattice coordinates')
plt.show()

plt.scatter(N_3, r_dev)
m, c = np.polyfit(N_3, r_dev, 1)
print(m, c)
plt.show()


'''plt.scatter(r_mean, list_m)
plt.xlabel('Lattice Size')
plt.ylabel('Mean of evolution of lattice coordinates')
plt.show()'''

'''plt.scatter(c_mean, list_m)
plt.xlabel('Lattice Size')
plt.ylabel('Mean of critical points')
plt.show()'''

'''plt.scatter(c_dev, list_m)
plt.xlabel('Lattice Size')
plt.ylabel('Deviation in critical points')
plt.show()'''
# Out:
# 0.0448774090243563 -0.5989168174413932
# -0.00014052753748476735 0.5989916691771516
# "plt.scatter(c_dev, list_m)\nplt.xlabel('Lattice Size')\nplt.ylabel('Deviation in critical points')\nplt.show()"

# %%
plt.hist(mean_evd2, bins=2000)
plt.show()
