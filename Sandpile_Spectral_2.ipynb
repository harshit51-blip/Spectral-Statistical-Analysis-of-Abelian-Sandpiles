# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import random as r
from itertools import chain
# %matplotlib notebook

# %%
#list_1 = np.array(np.arange(1,11,1))
#list_2 = np.array(np.arange(1,101,1).reshape(10,10))
'''b = r.choice(list_2)
b_2 = r.choice(b)'''
def func(mat):
    list_5 = []
    list_6 = []
    w_list = []
    list_7 = []
    list_8 = []
    
    
    for t in range(1000):
         
        for x in mat:
            a = r.choice(mat)
            j_prime = np.where(mat == a)
            a_2 = r.choice(a)
            j = np.where(mat[j_prime] == a_2)
            a_2 += 1
            mat[j_prime][j] = a_2
            list_7.append(a_2)

            list_3 = [x-1, x+1]
            for o in a:
                u = r.uniform(a_2**12+5,a_2**11+2)
                if o > u:
                    b = r.choice(list_3)
                    n = np.where(mat[j_prime] == o)
                    o -= abs(u-o)
                    b += abs(u-o)
                    mat[j_prime][n] = b
                    


                    '''if 0 == list_1[0]:
                        list_3 = [x+1]
                        b = r.choice(list_3)
                        n = np.where(list_1 == x)
                        x -= 1
                        b += 1
                        list_1[n] = b'''



                    if o == mat[j_prime][N-1]:
                        list_3 = [x-1]
                        b = r.choice(list_3)
                        n = np.where(mat[j_prime] == o)
                        o -= abs(u-o)
                        b += abs(u-o)
                        mat[j_prime][n] = b
                               
                list_6.append(u)   
                list_8.append(o)
            list_5.append(x)
        
        
        w = np.linalg.eigvals(mat)
        h = list(w)
        w_list.append(h)
        w_list.sort()
        
        
    return w_list, list_5, list_6, list_7, list_8

# %%
mat = np.random.random((100, 100))
math = mat + mat.conj().T

eig_vals, raw_list, crit_points, mean, neigh = func(math)

# %%
raw_list_2 =  list(chain.from_iterable(raw_list))
eig_vals_2 = list(chain.from_iterable(eig_vals))

norm_eig = [a/np.sqrt(100) for a in eig_vals_2]

rld2 = [y - x for x,y in zip(raw_list_2, raw_list_2[1:])]
evd2 = [abs(y - x) for x,y in zip(norm_eig, norm_eig[1:])]
mean_evd2 = evd2/np.mean(evd2)

# %%
print(len(norm_eig))
print(len(rld2))
print(len(evd2))
print(len(crit_points))
print(len(mean_evd2))

'''plt.scatter(np.log(rld2[:2999]), np.log(crit_points[:2999]))
plt.xlabel('log of lattice points in time (with previous states subtracted)')
plt.ylabel('log of critical points in time')
plt.title('evidence for spontaneous synchronicity')'''

plt.scatter(range(1000), crit_points[:1000])
plt.xlabel('time')
plt.ylabel('critical points')
plt.title('time vs critical points')
# Out:
# 100000
# 9999999
# 99999
# 10000000
# 99999
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'time vs critical points')

# %%
plt.hist(evd2, bins=2000)
plt.plot(density=True)
plt.xlim(0, 1)
plt.xlabel('absolute difference-eigen values')
plt.title('wigner distribution for a chaotic system; with the new cor. the eig vals came closer together')


'''s = np.linspace(0,0.116,1000000)
surmise = ((np.pi)*s/2)*(np.exp(-np.pi*s**(2/4)))
plt.plot(s, surmise, color='red')
plt.show()'''


'''print(st.stdev(evd2))
print(st.mean(evd2))
print(abs(min(evd2)-max(evd2)))'''
'''A = np.random.random((300, 300))
B = 2**-0.5 * (Mh)
D = np.linalg.eigvals(B)  
E = np.real(D)

plt.plot(list(np.arange(-0.001, 0.0008, 0.02)), E)'''

# %%
s = np.linspace(0,1.4)

surmise = (24.3*(np.pi*(s/2))*((np.exp(-2.1*np.pi*(s)**2)/4)))


plt.hist(9*mean_evd2, bins=1575, density=True, label='normed eigenvalue spacings')
plt.xlim(0,1.2)
plt.xlabel('absolute difference-eigen values')
plt.title('wigner distribution for a chaotic system; with the new cor. the eig vals came closer together')

plt.plot(s, surmise, label='wigner\'s surmise')

plt.legend()

# %%
plt.hist(norm_eig, bins=100)
plt.xlim(-1.25, 1.25)
plt.xlabel('eigen values')
plt.title('semi-circular law')

# %%
plt.hist(rld2)

# %%
from mpl_toolkits import mplot3d as m

fig = plt.figure()

ax = plt.axes(projection='3d')
plt.scatter(list(range(800)), rld2[:800], crit_points[:800])
ax.set_xlabel('time', fontsize=8)
ax.set_ylabel('lattice points (with previous states subtracted)', fontsize=6)
ax.set_zlabel('critical points', fontsize=8)
ax.set_title('time vs lattice points vs Critical Points')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0.92, 'time vs lattice points vs Critical Points')
