# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import random as r
import seaborn as sns
from itertools import chain
# %matplotlib notebook

# %%
#list_1 = np.array(np.arange(1,11,1))
#list_2 = np.array(np.arange(1,101,1).reshape(10,10))
'''b = r.choice(list_2)
b_2 = r.choice(b)'''
def func(N):
    list_5 = []
    list_6 = []
    w_list = []
    list_7 = []
    list_8 = []
    cout = []
    k_list = list(np.arange(1,10,1))
    counter = 0
    
    for t in range(500):
        
        mat = np.random.random((N,N))
        math = mat + mat.conj().T
        
        for x in math:
            
            a = r.choice(math)
            j_prime = np.where(math == a)
            a_2 = r.choice(a)
            j = np.where(math[j_prime] == a_2)
            a_2 += 1
            math[j_prime][j] = a_2
            list_7.append(a_2)

            list_3 = [x-1, x+1]
            for o in a:
                for k in k_list:
                    u = r.uniform(a_2**k + 5, a_2**(k-1) + 2)
                    if o > u:
                        b = r.choice(list_3)
                        n = np.where(math[j_prime] == o)
                        o -= abs(u-o)
                        b += abs(u-o)
                        math[j_prime][n] = b
                    


                        '''if 0 == list_1[0]:
                            list_3 = [x+1]
                            b = r.choice(list_3)
                            n = np.where(list_1 == x)
                            x -= 1
                            b += 1
                            list_1[n] = b'''



                        if o == math[j_prime][N-1]:
                            list_3 = [x-1]
                            b = r.choice(list_3)
                            n = np.where(math[j_prime] == o)
                            o -= abs(u-o)
                            b += abs(u-o)
                            math[j_prime][n] = b
                               
                   
                list_8.append(o)
                
                list_6.append(u)
                
            counter+=1
            
            list_5.append(x)
            cout.append(counter)
        
        
        w = np.linalg.eigvals(mat)
        h = list(w)
        w_list.append(h)
        w_list.sort()
        
        
    return w_list, list_5, list_6, list_7, cout

# %%
#N_list = [50, 60, 80, 100, 120, 150, 200, 240, 270, 300]
#N_2 = [200, 250, 300, 350, 400, 450, 500]
#N_3 = list(np.arange(5, 200, 10))
N_4 = [100]
list_m = []
list_c = []

for i in N_4:
    
    eig_vals, raw_list, crit_points, mean, clist = func(i)
    raw_list_2 =  list(chain.from_iterable(raw_list))
    eig_vals_2 = list(chain.from_iterable(eig_vals))
    norm_eig = [a/np.sqrt(i) for a in eig_vals_2]
    evd2 = [abs(y - x) for x,y in zip(norm_eig, norm_eig[1:])]
    mean_evd2 = evd2/(np.mean(evd2))
    rld2 = [y - x for x,y in zip(raw_list_2, raw_list_2[1:])]
    #d = {'list%s' % i: mean_evd2 for i in range(len(N_3))}
    #list_m.append(mean_evd2)
    list_c.append(crit_points)
    
    print('done')
# Out:
# done

# %%
'''lst0 = d["list0"]
lst1 = d["list1"]
lst2 = d["list2"]
lst3 = d["list3"]
lst4 = d["list4"]
lst5 = d["list5"]
lst6 = d["list6"]
lst7 = d["list7"]
lst8 = d["list8"]
lst9 = d["list9"]
#plt.bar(list(d.keys()), d.values(), 1.0)'''

# %%
'''plt.hist(d['list9'], bins=900, fill=False, ec='grey', label='9', density=True)
plt.hist(d['list8'], bins=900, fill=False, ec='aqua', label='8', density=True)
plt.hist(d['list7'], bins=900, fill=False, ec='gold', label='7', density=True)
plt.hist(d['list6'], bins=900, fill=False, ec='k', label='6', density=True)
plt.hist(d['list5'], bins=900, fill=False, ec='m', label='5', density=True)
plt.hist(d['list4'], bins=900, fill=False, ec='c', label='4', density=True)
plt.hist(d['list3'], bins=900, fill=False, ec='b', label='3', density=True)
plt.hist(d['list2'], bins=900, fill=False, ec='y', label='2', density=True)
plt.hist(d['list1'], bins=900, fill=False, ec='r', label='1', density=True)
plt.hist(d['list0'], bins=900, fill=False, ec='g', label='0', density=True)'''

'''fig, ax = plt.subplots()
for data in (d.values()):
    ax.hist(data, bins=900, histtype='step', fill=False, density=True)'''

#plt.hist(list_m, bins=150, histtype='step', fill=False, density=True)
ax.hist(evd2, bins=50, histtype='step', fill=False)
# Out:
# (array([9.0540e+03, 1.1429e+04, 1.1201e+04, 9.4720e+03, 6.6270e+03,
#         1.2170e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 2.0000e+00, 1.1400e+02, 5.2000e+01,
#         1.3100e+02, 4.1900e+02, 7.8000e+01, 9.9000e+01, 1.0400e+02]),
#  array([7.80820679e-04, 1.08484023e-01, 2.16187226e-01, 3.23890428e-01,
#         4.31593631e-01, 5.39296834e-01, 6.47000036e-01, 7.54703239e-01,
#         8.62406441e-01, 9.70109644e-01, 1.07781285e+00, 1.18551605e+00,
#         1.29321925e+00, 1.40092245e+00, 1.50862566e+00, 1.61632886e+00,
# ...

# %%
print(len(rld2))
# Out:
# 19999999

# %%
from mpl_toolkits import mplot3d as m

# %%
fig = plt.figure()

ax = plt.axes()

ax.scatter(raw_list_[10:5000], crit_points[10:5000])
#ax.hist(evd2, bins=50, histtype='step', fill=False)
#ax.hist(mean_evd2, bins=50, histtype='step', fill=False)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.hist(mean_evd2, bins=50, histtype='step', fill=False)
# Out:
# (array([9.0540e+03, 1.1429e+04, 1.1201e+04, 9.4720e+03, 6.6270e+03,
#         1.2170e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 2.0000e+00, 1.1400e+02, 5.2000e+01,
#         1.3100e+02, 4.1900e+02, 7.8000e+01, 9.9000e+01, 1.0400e+02]),
#  array([2.18485339e-03, 3.03554570e-01, 6.04924287e-01, 9.06294004e-01,
#         1.20766372e+00, 1.50903344e+00, 1.81040315e+00, 2.11177287e+00,
#         2.41314259e+00, 2.71451230e+00, 3.01588202e+00, 3.31725174e+00,
#         3.61862145e+00, 3.91999117e+00, 4.22136089e+00, 4.52273061e+00,
# ...
